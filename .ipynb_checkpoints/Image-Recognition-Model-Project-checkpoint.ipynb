# %%
import numpy as np
import pandas as pd
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./Model/Test_Image/Zayn.jpg')
if img is not None:
    print('variable is not None')
    print(img.shape)
else:
    print('variable is None')
# Out:
# variable is not None
# (1069, 800, 3)

# %%
import os
print(os.path.exists('./Model/Test_Image/Zayn.jpg'))
# Out:
# True

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1069, 800)

# %%
gray
# Out:
# array([[46, 46, 44, ..., 36, 46, 47],
#        [41, 45, 48, ..., 38, 46, 44],
#        [42, 45, 48, ..., 40, 44, 38],
#        ...,
#        [10, 15, 13, ..., 18, 42, 26],
#        [ 7, 11, 13, ..., 33, 35, 30],
#        [ 6,  8, 12, ..., 44, 23, 42]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('C:/Users/USER/Desktop/Machine_learning/Image_Recognition_Model_Project/Model/OpenCV/haarcascade_frontalface_default')
eye_cascade = cv2.CascadeClassifier('C:/Users/USER/Desktop/Machine_learning/Image_Recognition_Model_Project/Model/OpenCV/haarcascade_eye')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [23], in <cell line: 4>()
#       1 face_cascade = cv2.CascadeClassifier('C:/Users/USER/Desktop/Machine_learning/Image_Recognition_Model_Project/Model/OpenCV/haarcascade_frontalface_default')
#       2 eye_cascade = cv2.CascadeClassifier('C:/Users/USER/Desktop/Machine_learning/Image_Recognition_Model_Project/Model/OpenCV/haarcascade_eye')
# ----> 4 faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5 faces
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'

# %%
xlv1 = cv2.imread('./Model/OpenCV/haarcascade_frontalface_default')
if xlv1 is not None:
    print('variable is not None')
    print(img.shape)
else:
    print('variable is None')
# Out:
# variable is None
